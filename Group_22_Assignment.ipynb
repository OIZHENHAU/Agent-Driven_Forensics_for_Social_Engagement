# %% [markdown]
# <a href="https://colab.research.google.com/github/OIZHENHAU/Agent-Driven_Forensics_for_Social_Engagement/blob/dev/Group_22_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/OIZHENHAU/Agent-Driven_Forensics_for_Social_Engagement.git
# Out:
# Cloning into 'Agent-Driven_Forensics_for_Social_Engagement'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd Agent-Driven_Forensics_for_Social_Engagement
# Out:
# /content/Agent-Driven_Forensics_for_Social_Engagement

# %%
import shutil

# %%
# !ls /content
# Out:
# Agent-Driven_Forensics_for_Social_Engagement  sample_data

# %%
# !ls /content/Agent-Driven_Forensics_for_Social_Engagement
# Out:
# README.md

# %%
print("Hello World ! Zoossss! Like and Subscribe !")
# Out:
# Hello World ! Zoossss! Like and Subscribe !
